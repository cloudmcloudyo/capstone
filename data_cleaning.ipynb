# %% [markdown]
# # ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png) Capstone Project
#
# Data Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_colwidth', 0)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
script = pd.read_csv('./data/scripts.csv')
script.head()
# Out:
#    Unnamed: 0 Character  \
# 0  0           JERRY
# 1  1           JERRY
# 2  2           GEORGE
# 3  3           JERRY
# 4  4           GEORGE
#
# ...

# %%
info = pd.read_csv('./data/episode_info.csv')
info.head()
# Out:
#    Unnamed: 0  Season  EpisodeNo                Title    AirDate  \
# 0  0           1       1          Good News, Bad News  5-Jul-89
# 1  1           1       1          The Stakeout         31-May-90
# 2  2           1       2          The Robbery          7-Jun-90
# 3  3           1       3          Male Unbonding       14-Jun-90
# 4  4           1       4          The Stock Tip        21-Jun-90
#
#                        Writers      Director    SEID
# 0  Larry David, Jerry Seinfeld  Art Wolff     S01E01
# 1  Larry David, Jerry Seinfeld  Tom Cherones  S01E01
# 2  Matt Goldman                 Tom Cherones  S01E02
# 3  Larry David, Jerry Seinfeld  Tom Cherones  S01E03
# 4  Larry David, Jerry Seinfeld  Tom Cherones  S01E04
