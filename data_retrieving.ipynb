# %% [markdown]
# # ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png) Capstone Project
#
# Data Retrieving - Web Scraping

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.imsdb.com/TV/Seinfeld.html'
res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(res.content, 'lxml')

# %%
link = soup.find_all('a')

# %%
link
# Out:
# [<a href="https://www.imsdb.com" title="The Internet Movie Script Database"><img border="0" src="/images/logo_top.gif"/></a>,
#  <a href="https://www.imsdb.com" title="The Internet Movie Script Database"><img border="0" src="/images/logo_middle.gif"/></a>,
#  <a href="https://www.imsdb.com" title="The Internet Movie Script Database"><img border="0" src="/images/logo_bottom.gif" width="170"/></a>,
#  <a href="/alphabetical/0">#</a>,
#  <a href="/alphabetical/A">A</a>,
#  <a href="/alphabetical/B">B</a>,
#  <a href="/alphabetical/C">C</a>,
#  <a href="/alphabetical/D">D</a>,
#  <a href="/alphabetical/E">E</a>,
#  <a href="/alphabetical/F">F</a>,
#  <a href="/alphabetical/G">G</a>,
#  <a href="/alphabetical/H">H</a>,
#  <a href="/alphabetical/I">I</a>,
#  <a href="/alphabetical/J">J</a>,
#  <a href="/alphabetical/K">K</a>,
#  <a href="/alphabetical/L">L</a>,
#  <a href="/alphabetical/M">M</a>,
#  <a href="/alphabetical/N">N</a>,
#  <a href="/alphabetical/O">O</a>,
# ...

# %%
link = link[64:-7]
link
# Out:
# [<a href="/TV Transcripts/Seinfeld - Good News, Bad News Script.html" title="Good News, Bad News Script">Good News, Bad News</a>,
#  <a href="/TV Transcripts/Seinfeld - The Stakeout Script.html" title="The Stakeout Script">The Stakeout</a>,
#  <a href="/TV Transcripts/Seinfeld - The Robbery Script.html" title="The Robbery Script">The Robbery</a>,
#  <a href="/TV Transcripts/Seinfeld - Male Unbonding Script.html" title="Male Unbonding Script">Male Unbonding</a>,
#  <a href="/TV Transcripts/Seinfeld - The Stock Tip Script.html" title="The Stock Tip Script">The Stock Tip</a>,
#  <a href="/TV Transcripts/Seinfeld - The Ex-Girlfriend Script.html" title="The Ex-Girlfriend Script">The Ex-Girlfriend</a>,
#  <a href="/TV Transcripts/Seinfeld - The Pony Remark Script.html" title="The Pony Remark Script">The Pony Remark</a>,
#  <a href="/TV Transcripts/Seinfeld - The Jacket Script.html" title="The Jacket Script">The Jacket</a>,
# ...

# %%
link[0].text
# Out:
# 'Good News, Bad News'

# %%
branch = link[0].attrs['href']
branch
# Out:
# '/TV Transcripts/Seinfeld - Good News, Bad News Script.html'

# %%
branch_1 = branch[4:24]
branch_1 = branch_1.replace('T', 't')

# %%
branch_2 = branch[27:-12]
branch_2 = branch_2.replace(' ', '-')

# %%
branch_new = branch_1 + '-' + branch_2 + '.html'

# %%
url = url[:-16]
url
# Out:
# 'https://www.imsdb.com/'

# %%
ep_url = url + branch_new

# %%
ep_res = requests.get(ep_url)

# %%
ep_res.status_code
# Out:
# 200

# %%
ep_soup = BeautifulSoup(ep_res.content, 'lxml')

# %%
script = ep_soup.find('td', {'class': 'scrtext'})
script
# Out:
# <td class="scrtext">
# <pre>
# <b>
# </b><b>                       GOOD NEWS, BAD NEWS
# </b>
#
#
#                            Written by
#
#                   Larry David &amp; Jerry Seinfeld
#
#
#
#
# <b>
# </b>               (Comedy club)
#
# <b>
# </b><b>                             JERRY
# </b>               You know, why we're here? To be out,
#                this is out...and out is one of the
#                single most enjoyable experiences of
#                life. People...did you ever hear people
#                talking about "We should go out"? This
#                is what they're talking about...this
#                whole thing, we're all out now, no one
#                is home. Not one person here is home,
#                we're all out! There are people tryin'
#                to find us, they don't know where we
#                are. (imitates one of these people "tryin'
#                to find us"; pretends his hand is a
# ...

# %%
script_new = script.find_all('pre')[0]

# %%
script_new.contents
# Out:
# [' \n',
#  <b>
#  </b>,
#  <b>                       GOOD NEWS, BAD NEWS
#  </b>,
#  '\n\n\n                           Written by\n\n                  Larry David & Jerry Seinfeld\n\n\n\n\n',
#  <b>
#  </b>,
#  '               (Comedy club)\n\n',
#  <b>
#  </b>,
#  <b>                             JERRY
#  </b>,
# ...

# %%
for tag in script_new.contents[1:]:
    print (tag)
# Out:
#
#
# <b>
# </b>
# <b>                       GOOD NEWS, BAD NEWS
# </b>
#
#
#
#                            Written by
#
#                   Larry David & Jerry Seinfeld
#
#
#
#
#
# <b>
# </b>
#                (Comedy club)
#
#
# <b>
# </b>
# <b>                             JERRY
# </b>
#                You know, why we're here? To be out,
#                this is out...and out is one of the
#                single most enjoyable experiences of
#                life. People...did you ever hear people
#                talking about "We should go out"? This
#                is what they're talking about...this
#                whole thing, we're all out now, no one
#                is home. Not one person here is home,
#                we're all out! There are people tryin'
#                to find us, they don't know where we
#                are. (imitates one of these people "tryin'
#                to find us"; pretends his hand is a
# ...

# %%
# Credit to Dan Wilhelm for helping me work out these codes. Thanks so much!

tags = []
actor = ''
lines = []
scripts = []

for tag in script_new.contents:
    if tag.name == 'b':
        if tag.text.strip()!= '':
            if lines:
                scripts.append((actor, ' '.join(lines).replace('\n', ' ').replace('  ', '')))
                lines = []
            actor = tag.text.strip()
    else:
        text = tag.strip()
        if len(text)>0:
            lines.append(text)
scripts.append((actor, ' '.join(lines).replace('\n', ' ').replace('  ', '')))

# %%
scripts
# Out:
# [('GOOD NEWS, BAD NEWS',
#   'Written byLarry David & Jerry Seinfeld (Comedy club)'),
#  ('JERRY',
# ...
